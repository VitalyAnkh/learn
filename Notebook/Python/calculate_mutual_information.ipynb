# %%
import math
from nltk import bigrams
import collections

f=open("红楼梦-半本.txt")
a=f.read()
# a = """When the defendant and his lawyer walked into the court, some of the victim supporters turned their backs on him.  if we have more data then it will be more interesting because we have more chance to repeat bigrams. After some of the victim supporters turned their backs then a subset of the victim supporters turned around and left the court."""

a1 = a.split()
a2 = collections.Counter(a1)

a3 = collections.Counter(bigrams(a1))
a4 = sum([a2[x]for x in a2])
a5 = sum([a3[x]for x in a3])
a6 = {x: float(a2[x])/a4 for x in a2}  # word probabilities(w1 and w2)
a7 = {x: float(a3[x])/a5 for x in a3}  # joint probabilites (w1&w2)
u = {}
v = {}
for x in a6:
    k = {x: round(math.log((a7[b]/(a6[x] * a6[y])), 2), 4)
         for b in a7 for y in a6 if x and y in b}
    u[x] = k[x]
    k = {x: round(math.log((a7[b]/(a6[x] * a6[y])), 2), 4)
         for b in a7 for y in a6 if x in b and y in b}
    v[x] = k[x]

# %%
# sorted(u.items(),key=lambda item:item[1])

# %%
x+y

# %%
"hello"+"Vitaly"
# Out:
# 'helloVitaly'

# %%
x={}
x[("Hello","Vitaly")]=1

# %%
x
# Out:
# {('Hello', 'Vitaly'): 1}

# %%
from sklearn.metrics import mutual_info_score
import sys
import codecs
from string import punctuation
import jieba.posseg as pseg
import jieba.analyse
import jieba
import collections
from nltk import bigrams
import math
import nltk
nltk.download("punkt")

#a = """When the defendant and his lawyer walked into the court, some of the victim supporters turned their backs on him.  if we have more data then it will be more interesting because we have more chance to repeat bigrams. After some of the victim supporters turned their backs then a subset of the victim supporters turned around and left the court."""


# 预处理中文文本
if sys.getdefaultencoding() != 'utf-8':
    reload(sys)
    sys.setdefaultencoding('utf-8')
# 定义要删除的标点等字符
add_punc = '，。、【 】 “”：；（）《》‘’{}？！⑦()、%^>℃：.”“^-——=&#@￥'
all_punc = punctuation+add_punc

# def cut_words(sentence):
# print sentence
#    return " ".join(jieba.cut(sentence)).encode('utf-8')
# 指定要分词的文本
f = codecs.open('红楼梦-半本.txt', 'r', encoding="utf8")
# 指定分词结果的保存文本
target = codecs.open("处理过的红楼梦-半半本.txt", 'w', encoding="utf8")
print('open files')
line_num = 1
line = f.readline()
while line:

    print('---- processing ', line_num, ' article----------------')
    # 第一次分词，用于移除标点等符号
# line=re.sub(r'[A-Za-z0-9]|/d+','',line)   #用于移除英文和数字
    line_seg = " ".join(jieba.cut(line))
    # 移除标点等需要删除的符号
    testline = line_seg.split(' ')
    te2 = []
    for i in testline:
        te2.append(i)
        if i in all_punc:
            te2.remove(i)
    # 返回的te2是个list，转换为string后少了空格，因此需要再次分词
        # 第二次在仅汉字的基础上再次进行分词
    line_seg2 = " ".join(jieba.cut(''.join(te2)))
    target.writelines(line_seg2)
    line_num = line_num + 1
    line = f.readline()
f.close()
target.close()

f = open("处理过的红楼梦-半半本.txt")
a = f.read()

a1 = a.split()
a2 = collections.Counter(a1)

a3 = collections.Counter(bigrams(a1))
a4 = sum([a2[x]for x in a2])
a5 = sum([a3[x]for x in a3])
a6 = {x: float(a2[x])/a4 for x in a2}  # word probabilities(w1 and w2)
a7 = {x: float(a3[x])/a5 for x in a3}  # joint probabilites (w1&w2)
u = {}
v = {}
for x in a6:
    k = {x: round(math.log((a7[b]/(a6[x] * a6[y])), 2), 4)
         for b in a7 for y in a6 if x and y in b}
    u[x] = k[x]


def calc_MI(x, y, bins):
    c_xy = np.histogram2d(x, y, bins)[0]
    mi = mutual_info_score(None, None, contingency=c_xy)
    return mi


# bins = 5
# X = {}
# Y = {}
# MI = {}
# for x in X:
#     for y in Y:
#         MI[(x, y)] = calc_MI(x, y, bins)
# Out:
# [nltk_data] Downloading package punkt to /home/vitalyr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# open files
# ---- processing  1  article----------------
# ---- processing  2  article----------------
# ---- processing  3  article----------------
# ---- processing  4  article----------------
# ---- processing  5  article----------------
# ---- processing  6  article----------------
# ---- processing  7  article----------------
# ---- processing  8  article----------------
# ---- processing  9  article----------------
# ---- processing  10  article----------------
# ---- processing  11  article----------------
# ---- processing  12  article----------------
# ---- processing  13  article----------------
# ---- processing  14  article----------------
# ---- processing  15  article----------------
# ---- processing  16  article----------------
# ---- processing  17  article----------------
# ---- processing  18  article----------------
# ---- processing  19  article----------------
# ---- processing  20  article----------------
# ---- processing  21  article----------------
# ---- processing  22  article----------------
# ---- processing  23  article----------------
# ---- processing  24  article----------------
# ---- processing  25  article----------------
# ---- processing  26  article----------------
# ---- processing  27  article----------------
# ---- processing  28  article----------------
# ---- processing  29  article----------------
# ---- processing  30  article----------------
# ---- processing  31  article----------------
# ---- processing  32  article----------------
# ---- processing  33  article----------------
# ---- processing  34  article----------------
# ---- processing  35  article----------------
# ---- processing  36  article----------------
# ---- processing  37  article----------------
# ---- processing  38  article----------------
# ---- processing  39  article----------------
# ---- processing  40  article----------------
# ---- processing  41  article----------------
# ---- processing  42  article----------------
# ---- processing  43  article----------------
# ---- processing  44  article----------------
# ---- processing  45  article----------------
# ---- processing  46  article----------------
# ---- processing  47  article----------------
# ---- processing  48  article----------------
# ---- processing  49  article----------------
# ---- processing  50  article----------------
# ---- processing  51  article----------------
# ---- processing  52  article----------------
# ---- processing  53  article----------------
# ---- processing  54  article----------------
# ---- processing  55  article----------------
# ---- processing  56  article----------------
# ---- processing  57  article----------------
# ---- processing  58  article----------------
# ---- processing  59  article----------------
# ---- processing  60  article----------------
# ---- processing  61  article----------------
# ---- processing  62  article----------------
# ---- processing  63  article----------------
# ---- processing  64  article----------------
# ---- processing  65  article----------------
# ---- processing  66  article----------------
# ---- processing  67  article----------------
# ---- processing  68  article----------------
# ---- processing  69  article----------------
# ---- processing  70  article----------------
# ---- processing  71  article----------------
# ---- processing  72  article----------------
# ---- processing  73  article----------------
# ---- processing  74  article----------------
# ---- processing  75  article----------------
# ---- processing  76  article----------------
# ---- processing  77  article----------------
# ---- processing  78  article----------------
# ---- processing  79  article----------------
# ---- processing  80  article----------------
# ---- processing  81  article----------------
# ---- processing  82  article----------------
# ---- processing  83  article----------------
# ---- processing  84  article----------------
# ---- processing  85  article----------------
# ---- processing  86  article----------------
# ---- processing  87  article----------------
# ---- processing  88  article----------------
# ---- processing  89  article----------------
# ---- processing  90  article----------------
# ---- processing  91  article----------------
# ---- processing  92  article----------------
# ---- processing  93  article----------------
# ---- processing  94  article----------------
# ---- processing  95  article----------------
# ---- processing  96  article----------------
# ---- processing  97  article----------------
# ---- processing  98  article----------------
# ---- processing  99  article----------------
# ---- processing  100  article----------------
# ---- processing  101  article----------------
# ---- processing  102  article----------------
# ---- processing  103  article----------------
# ---- processing  104  article----------------
# ---- processing  105  article----------------
# ---- processing  106  article----------------
# ---- processing  107  article----------------
# ---- processing  108  article----------------
# ---- processing  109  article----------------
# ---- processing  110  article----------------
# ---- processing  111  article----------------
# ---- processing  112  article----------------
# ---- processing  113  article----------------
# ---- processing  114  article----------------
# ---- processing  115  article----------------
# ---- processing  116  article----------------
# ---- processing  117  article----------------
# ---- processing  118  article----------------
# ---- processing  119  article----------------
# ---- processing  120  article----------------
# ---- processing  121  article----------------
# ---- processing  122  article----------------
# ---- processing  123  article----------------
# ---- processing  124  article----------------
# ---- processing  125  article----------------
# ---- processing  126  article----------------
# ---- processing  127  article----------------
# ---- processing  128  article----------------
# ---- processing  129  article----------------
# ---- processing  130  article----------------
# ---- processing  131  article----------------
# ---- processing  132  article----------------
# ---- processing  133  article----------------
# ---- processing  134  article----------------
# ---- processing  135  article----------------
# ---- processing  136  article----------------
# ---- processing  137  article----------------
# ---- processing  138  article----------------
# ---- processing  139  article----------------
# ---- processing  140  article----------------
# ---- processing  141  article----------------
# ---- processing  142  article----------------
# ---- processing  143  article----------------
# ---- processing  144  article----------------
# ---- processing  145  article----------------
# ---- processing  146  article----------------
# ---- processing  147  article----------------
# ---- processing  148  article----------------
# ---- processing  149  article----------------
# ---- processing  150  article----------------
# ---- processing  151  article----------------
# ---- processing  152  article----------------
# ---- processing  153  article----------------
# ---- processing  154  article----------------
# ---- processing  155  article----------------
# ---- processing  156  article----------------
# ---- processing  157  article----------------
# ---- processing  158  article----------------
# ---- processing  159  article----------------
# ---- processing  160  article----------------
# ---- processing  161  article----------------
# ---- processing  162  article----------------
# ---- processing  163  article----------------
# ---- processing  164  article----------------
# ---- processing  165  article----------------
# ---- processing  166  article----------------
# ---- processing  167  article----------------
# ---- processing  168  article----------------
# ---- processing  169  article----------------
# ---- processing  170  article----------------
# ---- processing  171  article----------------
# ---- processing  172  article----------------
# ---- processing  173  article----------------
# ---- processing  174  article----------------
# ---- processing  175  article----------------
# ---- processing  176  article----------------
# ---- processing  177  article----------------
# ---- processing  178  article----------------
# ---- processing  179  article----------------
# ---- processing  180  article----------------
# ---- processing  181  article----------------
# ---- processing  182  article----------------
# ---- processing  183  article----------------
# ---- processing  184  article----------------
# ---- processing  185  article----------------
# ---- processing  186  article----------------
# ---- processing  187  article----------------
# ---- processing  188  article----------------
# ---- processing  189  article----------------
# ---- processing  190  article----------------
# ---- processing  191  article----------------
# ---- processing  192  article----------------
# ---- processing  193  article----------------
# ---- processing  194  article----------------
# ---- processing  195  article----------------
# ---- processing  196  article----------------
# ---- processing  197  article----------------
# ---- processing  198  article----------------
# ---- processing  199  article----------------
# ---- processing  200  article----------------
# ---- processing  201  article----------------
# ---- processing  202  article----------------
# ---- processing  203  article----------------
# ---- processing  204  article----------------
# ---- processing  205  article----------------
# ---- processing  206  article----------------
# ---- processing  207  article----------------
# ---- processing  208  article----------------
# ---- processing  209  article----------------
# ---- processing  210  article----------------
# ---- processing  211  article----------------
# ---- processing  212  article----------------
# ---- processing  213  article----------------
# ---- processing  214  article----------------
# ---- processing  215  article----------------
# ---- processing  216  article----------------
# ---- processing  217  article----------------
# ---- processing  218  article----------------
# ---- processing  219  article----------------
# ---- processing  220  article----------------
# ---- processing  221  article----------------
# ---- processing  222  article----------------
# ---- processing  223  article----------------
# ---- processing  224  article----------------
# ---- processing  225  article----------------
# ---- processing  226  article----------------
# ---- processing  227  article----------------
# ---- processing  228  article----------------
# ---- processing  229  article----------------
# ---- processing  230  article----------------
# ---- processing  231  article----------------
# ---- processing  232  article----------------
# ---- processing  233  article----------------
# ---- processing  234  article----------------
# ---- processing  235  article----------------
# ---- processing  236  article----------------
# ---- processing  237  article----------------
# ---- processing  238  article----------------
# ---- processing  239  article----------------
# ---- processing  240  article----------------
# ---- processing  241  article----------------
# ---- processing  242  article----------------
# ---- processing  243  article----------------
# ---- processing  244  article----------------
# ---- processing  245  article----------------
# ---- processing  246  article----------------
# ---- processing  247  article----------------
# ---- processing  248  article----------------
# ---- processing  249  article----------------
# ---- processing  250  article----------------
# ---- processing  251  article----------------
# ---- processing  252  article----------------
# ---- processing  253  article----------------
# ---- processing  254  article----------------
# ---- processing  255  article----------------
# ---- processing  256  article----------------
# ---- processing  257  article----------------
# ---- processing  258  article----------------
# ---- processing  259  article----------------
# ---- processing  260  article----------------
# ---- processing  261  article----------------
# ---- processing  262  article----------------
# ---- processing  263  article----------------
# ---- processing  264  article----------------
# ---- processing  265  article----------------
# ---- processing  266  article----------------
# ---- processing  267  article----------------
# ---- processing  268  article----------------
# ---- processing  269  article----------------
# ---- processing  270  article----------------
# ---- processing  271  article----------------
# ---- processing  272  article----------------
# ---- processing  273  article----------------
# ---- processing  274  article----------------
# ---- processing  275  article----------------
# ---- processing  276  article----------------
# ---- processing  277  article----------------
# ---- processing  278  article----------------
# ---- processing  279  article----------------
# ---- processing  280  article----------------
# ---- processing  281  article----------------
# ---- processing  282  article----------------
# ---- processing  283  article----------------
# ---- processing  284  article----------------
# ---- processing  285  article----------------
# ---- processing  286  article----------------
# ---- processing  287  article----------------
# ---- processing  288  article----------------
# ---- processing  289  article----------------
# ---- processing  290  article----------------
# ---- processing  291  article----------------
# ---- processing  292  article----------------
# ---- processing  293  article----------------
# ---- processing  294  article----------------
# ---- processing  295  article----------------
# ---- processing  296  article----------------
# ---- processing  297  article----------------
# ---- processing  298  article----------------
# ---- processing  299  article----------------
# ---- processing  300  article----------------
# ---- processing  301  article----------------
# ---- processing  302  article----------------
# ---- processing  303  article----------------
# ---- processing  304  article----------------
# ---- processing  305  article----------------
# ---- processing  306  article----------------
# ---- processing  307  article----------------
# ---- processing  308  article----------------
# ---- processing  309  article----------------
# ---- processing  310  article----------------
# ---- processing  311  article----------------
# ---- processing  312  article----------------
# ---- processing  313  article----------------
# ---- processing  314  article----------------
# ---- processing  315  article----------------
# ---- processing  316  article----------------
# ---- processing  317  article----------------
# ---- processing  318  article----------------
# ---- processing  319  article----------------
# ---- processing  320  article----------------
# ---- processing  321  article----------------
# ---- processing  322  article----------------
# ---- processing  323  article----------------
# ---- processing  324  article----------------
# ---- processing  325  article----------------
# ---- processing  326  article----------------
# ---- processing  327  article----------------
# ---- processing  328  article----------------
# ---- processing  329  article----------------
# ---- processing  330  article----------------
# ---- processing  331  article----------------
# ---- processing  332  article----------------
# ---- processing  333  article----------------
# ---- processing  334  article----------------
# ---- processing  335  article----------------
# ---- processing  336  article----------------
# ---- processing  337  article----------------
# ---- processing  338  article----------------
# ---- processing  339  article----------------
# ---- processing  340  article----------------
# ---- processing  341  article----------------
# ---- processing  342  article----------------
# ---- processing  343  article----------------
# ---- processing  344  article----------------
# ---- processing  345  article----------------
# ---- processing  346  article----------------
# ---- processing  347  article----------------
# ---- processing  348  article----------------
# ---- processing  349  article----------------
# ---- processing  350  article----------------
# ---- processing  351  article----------------
# ---- processing  352  article----------------
# ---- processing  353  article----------------
# ---- processing  354  article----------------
# ---- processing  355  article----------------
# ---- processing  356  article----------------
# ---- processing  357  article----------------
# ---- processing  358  article----------------
# ---- processing  359  article----------------
# ---- processing  360  article----------------
# ---- processing  361  article----------------
# ---- processing  362  article----------------
# ---- processing  363  article----------------
# ---- processing  364  article----------------
# ---- processing  365  article----------------
# ---- processing  366  article----------------
# ---- processing  367  article----------------
# ---- processing  368  article----------------
# ---- processing  369  article----------------
# ---- processing  370  article----------------
# ---- processing  371  article----------------
# ---- processing  372  article----------------
# ---- processing  373  article----------------
# ---- processing  374  article----------------
# ---- processing  375  article----------------
# ---- processing  376  article----------------
# ---- processing  377  article----------------
# ---- processing  378  article----------------
# ---- processing  379  article----------------
# ---- processing  380  article----------------
# ---- processing  381  article----------------
# ---- processing  382  article----------------
# ---- processing  383  article----------------
# ---- processing  384  article----------------
# ---- processing  385  article----------------
# ---- processing  386  article----------------
# ---- processing  387  article----------------
# ---- processing  388  article----------------
# ---- processing  389  article----------------
# ---- processing  390  article----------------
# ---- processing  391  article----------------
# ---- processing  392  article----------------
# ---- processing  393  article----------------
# ---- processing  394  article----------------
# ---- processing  395  article----------------
# ---- processing  396  article----------------
# ---- processing  397  article----------------
# ---- processing  398  article----------------
# ---- processing  399  article----------------
# ---- processing  400  article----------------
# ---- processing  401  article----------------
# ---- processing  402  article----------------
# ---- processing  403  article----------------
# ---- processing  404  article----------------
# ---- processing  405  article----------------
# ---- processing  406  article----------------
# ---- processing  407  article----------------
# ---- processing  408  article----------------
# ---- processing  409  article----------------
# ---- processing  410  article----------------
# ---- processing  411  article----------------
# ---- processing  412  article----------------
# ---- processing  413  article----------------
# ---- processing  414  article----------------
# ---- processing  415  article----------------
# ---- processing  416  article----------------
# ---- processing  417  article----------------
# ---- processing  418  article----------------
# ---- processing  419  article----------------
# ---- processing  420  article----------------
# ---- processing  421  article----------------
# ---- processing  422  article----------------
# ---- processing  423  article----------------
# ---- processing  424  article----------------
# ---- processing  425  article----------------
# ---- processing  426  article----------------
# ---- processing  427  article----------------
# ---- processing  428  article----------------
# ---- processing  429  article----------------
# ---- processing  430  article----------------
# ---- processing  431  article----------------
# ---- processing  432  article----------------
# ---- processing  433  article----------------
# ---- processing  434  article----------------
# ---- processing  435  article----------------
# ---- processing  436  article----------------
# ---- processing  437  article----------------
# ---- processing  438  article----------------
# ---- processing  439  article----------------
# ---- processing  440  article----------------
# ---- processing  441  article----------------
# ---- processing  442  article----------------
# ---- processing  443  article----------------
# ---- processing  444  article----------------
# ---- processing  445  article----------------
# ---- processing  446  article----------------
# ---- processing  447  article----------------
# ---- processing  448  article----------------
# ---- processing  449  article----------------
# ---- processing  450  article----------------
# ---- processing  451  article----------------
# ---- processing  452  article----------------
# ---- processing  453  article----------------
# ---- processing  454  article----------------
# ---- processing  455  article----------------
# ---- processing  456  article----------------
# ---- processing  457  article----------------
# ---- processing  458  article----------------
# ---- processing  459  article----------------
# ---- processing  460  article----------------
# ---- processing  461  article----------------
# ---- processing  462  article----------------
# ---- processing  463  article----------------
# ---- processing  464  article----------------
# ---- processing  465  article----------------
# ---- processing  466  article----------------
# ---- processing  467  article----------------
# ---- processing  468  article----------------
# ---- processing  469  article----------------
# ---- processing  470  article----------------
# ---- processing  471  article----------------
# ---- processing  472  article----------------
# ---- processing  473  article----------------
# ---- processing  474  article----------------
# ---- processing  475  article----------------
# ---- processing  476  article----------------
# ---- processing  477  article----------------
# ---- processing  478  article----------------
# ---- processing  479  article----------------
# ---- processing  480  article----------------
# ---- processing  481  article----------------
# ---- processing  482  article----------------
# ---- processing  483  article----------------
# ---- processing  484  article----------------
# ---- processing  485  article----------------
# ---- processing  486  article----------------
# ---- processing  487  article----------------
# ---- processing  488  article----------------
# ---- processing  489  article----------------
# ---- processing  490  article----------------
# ---- processing  491  article----------------
# ---- processing  492  article----------------
# ---- processing  493  article----------------
# ---- processing  494  article----------------
# ---- processing  495  article----------------
# ---- processing  496  article----------------
# ---- processing  497  article----------------
# ---- processing  498  article----------------
# ---- processing  499  article----------------
# ---- processing  500  article----------------
# ---- processing  501  article----------------
# ---- processing  502  article----------------
# ---- processing  503  article----------------
# ---- processing  504  article----------------
# ---- processing  505  article----------------
# ---- processing  506  article----------------
# ---- processing  507  article----------------
# ---- processing  508  article----------------
# ---- processing  509  article----------------
# ---- processing  510  article----------------
# ---- processing  511  article----------------
# ---- processing  512  article----------------
# ---- processing  513  article----------------
# ---- processing  514  article----------------
# ---- processing  515  article----------------
# ---- processing  516  article----------------
# ---- processing  517  article----------------
# ---- processing  518  article----------------
# ---- processing  519  article----------------
# ---- processing  520  article----------------
# ---- processing  521  article----------------
# ---- processing  522  article----------------
# ---- processing  523  article----------------
# ---- processing  524  article----------------
# ---- processing  525  article----------------
# ---- processing  526  article----------------
# ---- processing  527  article----------------
# ---- processing  528  article----------------
# ---- processing  529  article----------------
# ---- processing  530  article----------------
# ---- processing  531  article----------------
# ---- processing  532  article----------------
# ---- processing  533  article----------------
# ---- processing  534  article----------------
# ---- processing  535  article----------------
# ---- processing  536  article----------------
# ---- processing  537  article----------------
# ---- processing  538  article----------------
# ---- processing  539  article----------------
# ---- processing  540  article----------------
# ---- processing  541  article----------------
# ---- processing  542  article----------------
# ---- processing  543  article----------------
# ---- processing  544  article----------------
# ---- processing  545  article----------------
# ---- processing  546  article----------------
# ---- processing  547  article----------------
# ---- processing  548  article----------------
# ---- processing  549  article----------------
# ---- processing  550  article----------------
# ---- processing  551  article----------------
# ---- processing  552  article----------------
# ---- processing  553  article----------------
# ---- processing  554  article----------------
# ---- processing  555  article----------------
# ---- processing  556  article----------------
# ---- processing  557  article----------------
# ---- processing  558  article----------------
# ---- processing  559  article----------------
# ---- processing  560  article----------------
# ---- processing  561  article----------------
# ---- processing  562  article----------------
# ---- processing  563  article----------------
# ---- processing  564  article----------------
# ---- processing  565  article----------------
# ---- processing  566  article----------------
# ---- processing  567  article----------------
# ---- processing  568  article----------------
# ---- processing  569  article----------------
# ---- processing  570  article----------------
# ---- processing  571  article----------------
# ---- processing  572  article----------------
# ---- processing  573  article----------------
# ---- processing  574  article----------------
# ---- processing  575  article----------------
# ---- processing  576  article----------------
# ---- processing  577  article----------------
# ---- processing  578  article----------------
# ---- processing  579  article----------------
# ---- processing  580  article----------------
# ---- processing  581  article----------------
# ---- processing  582  article----------------
# ---- processing  583  article----------------
# ---- processing  584  article----------------
# ---- processing  585  article----------------
# ---- processing  586  article----------------
# ---- processing  587  article----------------
# ---- processing  588  article----------------
# ---- processing  589  article----------------
# ---- processing  590  article----------------
# ---- processing  591  article----------------
# ---- processing  592  article----------------
# ---- processing  593  article----------------
# ---- processing  594  article----------------
# ---- processing  595  article----------------
# ---- processing  596  article----------------
# ---- processing  597  article----------------
# ---- processing  598  article----------------
# ---- processing  599  article----------------
# ---- processing  600  article----------------
# ---- processing  601  article----------------
# ---- processing  602  article----------------
# ---- processing  603  article----------------
# ---- processing  604  article----------------
# ---- processing  605  article----------------
# ---- processing  606  article----------------
# ---- processing  607  article----------------
# ---- processing  608  article----------------
# ---- processing  609  article----------------
# ---- processing  610  article----------------
# ---- processing  611  article----------------
# ---- processing  612  article----------------
# ---- processing  613  article----------------
# ---- processing  614  article----------------
# ---- processing  615  article----------------
# ---- processing  616  article----------------
# ---- processing  617  article----------------
# ---- processing  618  article----------------
# ---- processing  619  article----------------
# ---- processing  620  article----------------
# ---- processing  621  article----------------
# ---- processing  622  article----------------
# ---- processing  623  article----------------
# ---- processing  624  article----------------
# ---- processing  625  article----------------
# ---- processing  626  article----------------
# ---- processing  627  article----------------
# ---- processing  628  article----------------
# ---- processing  629  article----------------
# ---- processing  630  article----------------
# ---- processing  631  article----------------
# ---- processing  632  article----------------
# ---- processing  633  article----------------
# ---- processing  634  article----------------
# ---- processing  635  article----------------
# ---- processing  636  article----------------
# ---- processing  637  article----------------
# ---- processing  638  article----------------
# ---- processing  639  article----------------
# ---- processing  640  article----------------
# ---- processing  641  article----------------
# ---- processing  642  article----------------
# ---- processing  643  article----------------
# ---- processing  644  article----------------
# ---- processing  645  article----------------
# ---- processing  646  article----------------
# ---- processing  647  article----------------
# ---- processing  648  article----------------
# ---- processing  649  article----------------
# ---- processing  650  article----------------
# ---- processing  651  article----------------
# ---- processing  652  article----------------
# ---- processing  653  article----------------
# ---- processing  654  article----------------
# ---- processing  655  article----------------
# ---- processing  656  article----------------
# ---- processing  657  article----------------
# ---- processing  658  article----------------
# ---- processing  659  article----------------
# ---- processing  660  article----------------
# ---- processing  661  article----------------
# ---- processing  662  article----------------
# ---- processing  663  article----------------
# ---- processing  664  article----------------
# ---- processing  665  article----------------
# ---- processing  666  article----------------
# ---- processing  667  article----------------
# ---- processing  668  article----------------
# ---- processing  669  article----------------
# ---- processing  670  article----------------
# ---- processing  671  article----------------
# ---- processing  672  article----------------
# ---- processing  673  article----------------
# ---- processing  674  article----------------
# ---- processing  675  article----------------
# ---- processing  676  article----------------
# ---- processing  677  article----------------
# ---- processing  678  article----------------
# ---- processing  679  article----------------
# ---- processing  680  article----------------
# ---- processing  681  article----------------
# ---- processing  682  article----------------
# ---- processing  683  article----------------
# ---- processing  684  article----------------
# ---- processing  685  article----------------
# ---- processing  686  article----------------
# ---- processing  687  article----------------
# ---- processing  688  article----------------
# ---- processing  689  article----------------
# ---- processing  690  article----------------
# ---- processing  691  article----------------
# ---- processing  692  article----------------
# ---- processing  693  article----------------
# ---- processing  694  article----------------
# ---- processing  695  article----------------
# ---- processing  696  article----------------
# ---- processing  697  article----------------
# ---- processing  698  article----------------
# ---- processing  699  article----------------
# ---- processing  700  article----------------
# ---- processing  701  article----------------
# ---- processing  702  article----------------
# ---- processing  703  article----------------
# ---- processing  704  article----------------
# ---- processing  705  article----------------
# ---- processing  706  article----------------
# ---- processing  707  article----------------
# ---- processing  708  article----------------
# ---- processing  709  article----------------
# ---- processing  710  article----------------
# ---- processing  711  article----------------
# ---- processing  712  article----------------
# ---- processing  713  article----------------
# ---- processing  714  article----------------
# ---- processing  715  article----------------
# ---- processing  716  article----------------
# ---- processing  717  article----------------
# ---- processing  718  article----------------
# ---- processing  719  article----------------
# ---- processing  720  article----------------
# ---- processing  721  article----------------
# ---- processing  722  article----------------
# ---- processing  723  article----------------
# ---- processing  724  article----------------
# ---- processing  725  article----------------
# ---- processing  726  article----------------
# ---- processing  727  article----------------
# ---- processing  728  article----------------
# ---- processing  729  article----------------
# ---- processing  730  article----------------
# ---- processing  731  article----------------
# ---- processing  732  article----------------
# ---- processing  733  article----------------
# ---- processing  734  article----------------
# ---- processing  735  article----------------
# ---- processing  736  article----------------
# ---- processing  737  article----------------
# ---- processing  738  article----------------
# ---- processing  739  article----------------
# ---- processing  740  article----------------
# ---- processing  741  article----------------
# ---- processing  742  article----------------
# ---- processing  743  article----------------
# ---- processing  744  article----------------
# ---- processing  745  article----------------
# ---- processing  746  article----------------
# ---- processing  747  article----------------
# ---- processing  748  article----------------
# ---- processing  749  article----------------
# ---- processing  750  article----------------
# ---- processing  751  article----------------
# ---- processing  752  article----------------
# ---- processing  753  article----------------
# ---- processing  754  article----------------
# ---- processing  755  article----------------
# ---- processing  756  article----------------
# ---- processing  757  article----------------
# ---- processing  758  article----------------
# ---- processing  759  article----------------
# ---- processing  760  article----------------
# ---- processing  761  article----------------
# ---- processing  762  article----------------
# ---- processing  763  article----------------
# ---- processing  764  article----------------
# ---- processing  765  article----------------
# ---- processing  766  article----------------
# ---- processing  767  article----------------
# ---- processing  768  article----------------
# ---- processing  769  article----------------
# ---- processing  770  article----------------
# ---- processing  771  article----------------
# ---- processing  772  article----------------
# ---- processing  773  article----------------
# ---- processing  774  article----------------
# ---- processing  775  article----------------
# ---- processing  776  article----------------
# ---- processing  777  article----------------
# ---- processing  778  article----------------
# ---- processing  779  article----------------
# ---- processing  780  article----------------
# ---- processing  781  article----------------
# ---- processing  782  article----------------
# ---- processing  783  article----------------
# ---- processing  784  article----------------
# ---- processing  785  article----------------
# ---- processing  786  article----------------
# ---- processing  787  article----------------
# ---- processing  788  article----------------
# ---- processing  789  article----------------
# ---- processing  790  article----------------
# ---- processing  791  article----------------
# ---- processing  792  article----------------
# ---- processing  793  article----------------
# ---- processing  794  article----------------
# ---- processing  795  article----------------
# ---- processing  796  article----------------
# ---- processing  797  article----------------
# ---- processing  798  article----------------
# ---- processing  799  article----------------
# ---- processing  800  article----------------
# ---- processing  801  article----------------
# ---- processing  802  article----------------
# ---- processing  803  article----------------
# ---- processing  804  article----------------
# ---- processing  805  article----------------
# ---- processing  806  article----------------
# ---- processing  807  article----------------
# ---- processing  808  article----------------
# ---- processing  809  article----------------
# ---- processing  810  article----------------
# ---- processing  811  article----------------
# ---- processing  812  article----------------
# ---- processing  813  article----------------
# ---- processing  814  article----------------
# ---- processing  815  article----------------
# ---- processing  816  article----------------
# ---- processing  817  article----------------
# ---- processing  818  article----------------
# ---- processing  819  article----------------
# ---- processing  820  article----------------
# ---- processing  821  article----------------
# ---- processing  822  article----------------
# ---- processing  823  article----------------
# ---- processing  824  article----------------
# ---- processing  825  article----------------
# ---- processing  826  article----------------
# ---- processing  827  article----------------
# ---- processing  828  article----------------
# ---- processing  829  article----------------
# ---- processing  830  article----------------
# ---- processing  831  article----------------
# ---- processing  832  article----------------
# ---- processing  833  article----------------
# ---- processing  834  article----------------
# ---- processing  835  article----------------
# ---- processing  836  article----------------
# ---- processing  837  article----------------
# ---- processing  838  article----------------
# ---- processing  839  article----------------
# ---- processing  840  article----------------
# ---- processing  841  article----------------
# ---- processing  842  article----------------
# ---- processing  843  article----------------
# ---- processing  844  article----------------
# ---- processing  845  article----------------
# ---- processing  846  article----------------
# ---- processing  847  article----------------
# ---- processing  848  article----------------
# ---- processing  849  article----------------
# ---- processing  850  article----------------
# ---- processing  851  article----------------
# ---- processing  852  article----------------
# ---- processing  853  article----------------
# ---- processing  854  article----------------
# ---- processing  855  article----------------
# ---- processing  856  article----------------
# ---- processing  857  article----------------
# ---- processing  858  article----------------
# ---- processing  859  article----------------
# ---- processing  860  article----------------
# ---- processing  861  article----------------
# ---- processing  862  article----------------
# ---- processing  863  article----------------
# ---- processing  864  article----------------
# ---- processing  865  article----------------
# ---- processing  866  article----------------
# ---- processing  867  article----------------
# ---- processing  868  article----------------
# ---- processing  869  article----------------
# ---- processing  870  article----------------
# ---- processing  871  article----------------
# ---- processing  872  article----------------
# ---- processing  873  article----------------
# ---- processing  874  article----------------
# ---- processing  875  article----------------
# ---- processing  876  article----------------
# ---- processing  877  article----------------
# ---- processing  878  article----------------
# ---- processing  879  article----------------
# ---- processing  880  article----------------
# ---- processing  881  article----------------
# ---- processing  882  article----------------
# ---- processing  883  article----------------
# ---- processing  884  article----------------
# ---- processing  885  article----------------
# ---- processing  886  article----------------
# ---- processing  887  article----------------
# ---- processing  888  article----------------
# ---- processing  889  article----------------
# ---- processing  890  article----------------
# ---- processing  891  article----------------
# ---- processing  892  article----------------
# ---- processing  893  article----------------
# ---- processing  894  article----------------
# ---- processing  895  article----------------
# ---- processing  896  article----------------
# ---- processing  897  article----------------
# ---- processing  898  article----------------
# ---- processing  899  article----------------
# ---- processing  900  article----------------
# ---- processing  901  article----------------
# ---- processing  902  article----------------
# ---- processing  903  article----------------
# ---- processing  904  article----------------
# ---- processing  905  article----------------
# ---- processing  906  article----------------
# ---- processing  907  article----------------
# ---- processing  908  article----------------
# ---- processing  909  article----------------
# ---- processing  910  article----------------
# ---- processing  911  article----------------
# ---- processing  912  article----------------
# ---- processing  913  article----------------
# ---- processing  914  article----------------
# ---- processing  915  article----------------
# ---- processing  916  article----------------
# ---- processing  917  article----------------
# ---- processing  918  article----------------
# ---- processing  919  article----------------
# ---- processing  920  article----------------
# ---- processing  921  article----------------
# ---- processing  922  article----------------
# ---- processing  923  article----------------
# ---- processing  924  article----------------
# ---- processing  925  article----------------
# ---- processing  926  article----------------
# ---- processing  927  article----------------
# ---- processing  928  article----------------
# ---- processing  929  article----------------
# ---- processing  930  article----------------
# ---- processing  931  article----------------
# ---- processing  932  article----------------
# ---- processing  933  article----------------
# ---- processing  934  article----------------
# ---- processing  935  article----------------
# ---- processing  936  article----------------
# ---- processing  937  article----------------
# ---- processing  938  article----------------
# ---- processing  939  article----------------
# ---- processing  940  article----------------
# ---- processing  941  article----------------
# ---- processing  942  article----------------
# ---- processing  943  article----------------
# ---- processing  944  article----------------
# ---- processing  945  article----------------
# ---- processing  946  article----------------
# ---- processing  947  article----------------
# ---- processing  948  article----------------
# ---- processing  949  article----------------
# ---- processing  950  article----------------
# ---- processing  951  article----------------
# ---- processing  952  article----------------
# ---- processing  953  article----------------
# ---- processing  954  article----------------
# ---- processing  955  article----------------
# ---- processing  956  article----------------
# ---- processing  957  article----------------
# ---- processing  958  article----------------
# ---- processing  959  article----------------
# ---- processing  960  article----------------
# ---- processing  961  article----------------
# ---- processing  962  article----------------
# ---- processing  963  article----------------
# ---- processing  964  article----------------
# ---- processing  965  article----------------
# ---- processing  966  article----------------
# ---- processing  967  article----------------
# ---- processing  968  article----------------
# ---- processing  969  article----------------
# ---- processing  970  article----------------
# ---- processing  971  article----------------
# ---- processing  972  article----------------
# ---- processing  973  article----------------
# ---- processing  974  article----------------
# ---- processing  975  article----------------
# ---- processing  976  article----------------
# ---- processing  977  article----------------
# ---- processing  978  article----------------
# ---- processing  979  article----------------
# ---- processing  980  article----------------
# ---- processing  981  article----------------
# ---- processing  982  article----------------
# ---- processing  983  article----------------
# ---- processing  984  article----------------
# ---- processing  985  article----------------
# ---- processing  986  article----------------
# ---- processing  987  article----------------
# ---- processing  988  article----------------
# ---- processing  989  article----------------
# ---- processing  990  article----------------
# ---- processing  991  article----------------
# ---- processing  992  article----------------
# ---- processing  993  article----------------
# ---- processing  994  article----------------
# ---- processing  995  article----------------
# ---- processing  996  article----------------
# ---- processing  997  article----------------
# ---- processing  998  article----------------
# ---- processing  999  article----------------
# ---- processing  1000  article----------------
# ---- processing  1001  article----------------
# ---- processing  1002  article----------------
# ---- processing  1003  article----------------
# ---- processing  1004  article----------------
# ---- processing  1005  article----------------
# ---- processing  1006  article----------------
# ---- processing  1007  article----------------
# ---- processing  1008  article----------------
# ---- processing  1009  article----------------
# ---- processing  1010  article----------------
# ---- processing  1011  article----------------
# ---- processing  1012  article----------------
# ---- processing  1013  article----------------
# ---- processing  1014  article----------------
# ---- processing  1015  article----------------
# ---- processing  1016  article----------------
# ---- processing  1017  article----------------
# ---- processing  1018  article----------------
# ---- processing  1019  article----------------
# ---- processing  1020  article----------------
# ---- processing  1021  article----------------
# ---- processing  1022  article----------------
# ---- processing  1023  article----------------
# ---- processing  1024  article----------------
# ---- processing  1025  article----------------
# ---- processing  1026  article----------------
# ---- processing  1027  article----------------
# ---- processing  1028  article----------------
# ---- processing  1029  article----------------
# ---- processing  1030  article----------------
# ---- processing  1031  article----------------
# ---- processing  1032  article----------------
# ---- processing  1033  article----------------
# ---- processing  1034  article----------------
# ---- processing  1035  article----------------
# ---- processing  1036  article----------------
# ---- processing  1037  article----------------
# ---- processing  1038  article----------------
# ---- processing  1039  article----------------
# ---- processing  1040  article----------------
# ---- processing  1041  article----------------
# ---- processing  1042  article----------------
# ...
# ---- processing  1120  article----------------
# ---- processing  1121  article----------------
# ---- processing  1122  article----------------
# ---- processing  1123  article----------------
# ---- processing  1124  article----------------
# ---- processing  1125  article----------------
# ---- processing  1126  article----------------
# ---- processing  1127  article----------------
# ---- processing  1128  article----------------
# ---- processing  1129  article----------------
# ---- processing  1130  article----------------
# ---- processing  1131  article----------------
# ---- processing  1132  article----------------
# ---- processing  1133  article----------------
# ---- processing  1134  article----------------
# ---- processing  1135  article----------------
# ---- processing  1136  article----------------
# ---- processing  1137  article----------------
# ---- processing  1138  article----------------
# ---- processing  1139  article----------------
# ---- processing  1140  article----------------
# ---- processing  1141  article----------------
# ---- processing  1142  article----------------
# ---- processing  1143  article----------------
# ---- processing  1144  article----------------
# ---- processing  1145  article----------------
# ---- processing  1146  article----------------
# ---- processing  1147  article----------------
# ---- processing  1148  article----------------
# ---- processing  1149  article----------------
# ---- processing  1150  article----------------
# ---- processing  1151  article----------------
# ---- processing  1152  article----------------
# ---- processing  1153  article----------------
# ---- processing  1154  article----------------
# ---- processing  1155  article----------------
# ---- processing  1156  article----------------
# ---- processing  1157  article----------------
# ---- processing  1158  article----------------
# ---- processing  1159  article----------------
# ---- processing  1160  article----------------
# ---- processing  1161  article----------------
# ---- processing  1162  article----------------
# ---- processing  1163  article----------------
# ---- processing  1164  article----------------
# ---- processing  1165  article----------------
# ---- processing  1166  article----------------
# ---- processing  1167  article----------------
# ---- processing  1168  article----------------
# ---- processing  1169  article----------------
# ---- processing  1170  article----------------
# ---- processing  1171  article----------------
# ---- processing  1172  article----------------
# ---- processing  1173  article----------------
# ---- processing  1174  article----------------
# ---- processing  1175  article----------------
# ---- processing  1176  article----------------
# ---- processing  1177  article----------------
# ---- processing  1178  article----------------
# ---- processing  1179  article----------------
# ---- processing  1180  article----------------
# ---- processing  1181  article----------------
# ---- processing  1182  article----------------
# ---- processing  1183  article----------------
# ---- processing  1184  article----------------
# ---- processing  1185  article----------------
# ---- processing  1186  article----------------
# ---- processing  1187  article----------------
# ---- processing  1188  article----------------
# ---- processing  1189  article----------------
# ---- processing  1190  article----------------
# ---- processing  1191  article----------------
# ---- processing  1192  article----------------
# ---- processing  1193  article----------------
# ---- processing  1194  article----------------
# ---- processing  1195  article----------------
# ---- processing  1196  article----------------
# ---- processing  1197  article----------------
# ---- processing  1198  article----------------
# ---- processing  1199  article----------------
# ---- processing  1200  article----------------
# ---- processing  1201  article----------------
# ---- processing  1202  article----------------
# ---- processing  1203  article----------------
# ---- processing  1204  article----------------
# ---- processing  1205  article----------------
# ---- processing  1206  article----------------
# ---- processing  1207  article----------------
# ---- processing  1208  article----------------
# ---- processing  1209  article----------------
# ---- processing  1210  article----------------
# ---- processing  1211  article----------------
# ---- processing  1212  article----------------
# ---- processing  1213  article----------------
# ---- processing  1214  article----------------
# ---- processing  1215  article----------------
# ---- processing  1216  article----------------
# ---- processing  1217  article----------------
# ---- processing  1218  article----------------
# ---- processing  1219  article----------------
# ---- processing  1220  article----------------
# ---- processing  1221  article----------------
# ---- processing  1222  article----------------
# ---- processing  1223  article----------------
# ---- processing  1224  article----------------
# ---- processing  1225  article----------------
# ---- processing  1226  article----------------
# ---- processing  1227  article----------------
# ---- processing  1228  article----------------
# ---- processing  1229  article----------------
# ---- processing  1230  article----------------
# ---- processing  1231  article----------------
# ---- processing  1232  article----------------
# ---- processing  1233  article----------------
# ---- processing  1234  article----------------
# ---- processing  1235  article----------------
# ---- processing  1236  article----------------
# ---- processing  1237  article----------------
# ---- processing  1238  article----------------
# ---- processing  1239  article----------------
# ---- processing  1240  article----------------
# ---- processing  1241  article----------------
# ---- processing  1242  article----------------
# ---- processing  1243  article----------------
# ---- processing  1244  article----------------
# ---- processing  1245  article----------------
# ---- processing  1246  article----------------
# ---- processing  1247  article----------------
# ---- processing  1248  article----------------
# ---- processing  1249  article----------------
# ---- processing  1250  article----------------
# ---- processing  1251  article----------------
# ---- processing  1252  article----------------
# ---- processing  1253  article----------------
# ---- processing  1254  article----------------
# ---- processing  1255  article----------------
# ---- processing  1256  article----------------
# ---- processing  1257  article----------------
# ---- processing  1258  article----------------
# ---- processing  1259  article----------------
# ---- processing  1260  article----------------
# ---- processing  1261  article----------------
# ---- processing  1262  article----------------
# ---- processing  1263  article----------------
# ---- processing  1264  article----------------
# ---- processing  1265  article----------------
# ---- processing  1266  article----------------
# ---- processing  1267  article----------------
# ---- processing  1268  article----------------
# ---- processing  1269  article----------------
# ---- processing  1270  article----------------
# ---- processing  1271  article----------------
# ---- processing  1272  article----------------
# ---- processing  1273  article----------------
# ---- processing  1274  article----------------
# ---- processing  1275  article----------------
# ---- processing  1276  article----------------
# ---- processing  1277  article----------------
# ---- processing  1278  article----------------
# ---- processing  1279  article----------------
# ---- processing  1280  article----------------
# ---- processing  1281  article----------------
# ---- processing  1282  article----------------
# ---- processing  1283  article----------------
# ---- processing  1284  article----------------
# ---- processing  1285  article----------------
# ---- processing  1286  article----------------
# ---- processing  1287  article----------------
# ---- processing  1288  article----------------
# ---- processing  1289  article----------------
# ---- processing  1290  article----------------
# ---- processing  1291  article----------------
# ---- processing  1292  article----------------
# ---- processing  1293  article----------------
# ---- processing  1294  article----------------
# ---- processing  1295  article----------------
# ---- processing  1296  article----------------
# ---- processing  1297  article----------------
# ---- processing  1298  article----------------
# ---- processing  1299  article----------------
# ---- processing  1300  article----------------
# ---- processing  1301  article----------------
# ---- processing  1302  article----------------
# ---- processing  1303  article----------------
# ---- processing  1304  article----------------
# ---- processing  1305  article----------------
# ---- processing  1306  article----------------
# ---- processing  1307  article----------------
# ---- processing  1308  article----------------
# ---- processing  1309  article----------------
# ---- processing  1310  article----------------
# ---- processing  1311  article----------------
# ---- processing  1312  article----------------
# ---- processing  1313  article----------------
# ---- processing  1314  article----------------
# ---- processing  1315  article----------------
# ---- processing  1316  article----------------
# ---- processing  1317  article----------------
# ---- processing  1318  article----------------
# ---- processing  1319  article----------------
# ---- processing  1320  article----------------
# ---- processing  1321  article----------------
# ---- processing  1322  article----------------
# ---- processing  1323  article----------------
# ---- processing  1324  article----------------
# ---- processing  1325  article----------------
# ---- processing  1326  article----------------
# ---- processing  1327  article----------------
# ---- processing  1328  article----------------
# ---- processing  1329  article----------------
# ---- processing  1330  article----------------
# ---- processing  1331  article----------------
# ---- processing  1332  article----------------
# ---- processing  1333  article----------------
# ---- processing  1334  article----------------
# ---- processing  1335  article----------------
# ---- processing  1336  article----------------
# ---- processing  1337  article----------------
# ---- processing  1338  article----------------
# ---- processing  1339  article----------------
# ---- processing  1340  article----------------
# ---- processing  1341  article----------------
# ---- processing  1342  article----------------
# ---- processing  1343  article----------------
# ---- processing  1344  article----------------
# ---- processing  1345  article----------------
# ---- processing  1346  article----------------
# ---- processing  1347  article----------------
# ---- processing  1348  article----------------
# ---- processing  1349  article----------------
# ---- processing  1350  article----------------
# ---- processing  1351  article----------------
# ---- processing  1352  article----------------
# ---- processing  1353  article----------------
# ---- processing  1354  article----------------
# ---- processing  1355  article----------------
# ---- processing  1356  article----------------
# ---- processing  1357  article----------------
# ---- processing  1358  article----------------
# ---- processing  1359  article----------------
# ---- processing  1360  article----------------
# ---- processing  1361  article----------------
# ---- processing  1362  article----------------
# ---- processing  1363  article----------------
# ---- processing  1364  article----------------
# ---- processing  1365  article----------------
# ---- processing  1366  article----------------
# ---- processing  1367  article----------------
# ---- processing  1368  article----------------
# ---- processing  1369  article----------------
# ---- processing  1370  article----------------
# ---- processing  1371  article----------------
# ---- processing  1372  article----------------
# ---- processing  1373  article----------------
# ---- processing  1374  article----------------
# ---- processing  1375  article----------------
# ---- processing  1376  article----------------
# ---- processing  1377  article----------------
# ---- processing  1378  article----------------
# ---- processing  1379  article----------------
# ---- processing  1380  article----------------
# ---- processing  1381  article----------------
# ---- processing  1382  article----------------
# ---- processing  1383  article----------------
# ---- processing  1384  article----------------
# ---- processing  1385  article----------------
# ---- processing  1386  article----------------
# ---- processing  1387  article----------------
# ---- processing  1388  article----------------
# ---- processing  1389  article----------------
# ---- processing  1390  article----------------
# ---- processing  1391  article----------------
# ---- processing  1392  article----------------
# ---- processing  1393  article----------------
# ---- processing  1394  article----------------
# ---- processing  1395  article----------------
# ---- processing  1396  article----------------
# ---- processing  1397  article----------------
# ---- processing  1398  article----------------
# ---- processing  1399  article----------------
# ---- processing  1400  article----------------
# ---- processing  1401  article----------------
# ---- processing  1402  article----------------
# ---- processing  1403  article----------------
# ---- processing  1404  article----------------
# ---- processing  1405  article----------------
# ---- processing  1406  article----------------
# ---- processing  1407  article----------------
# ---- processing  1408  article----------------
# ---- processing  1409  article----------------
# ---- processing  1410  article----------------
# ---- processing  1411  article----------------
# ---- processing  1412  article----------------
# ---- processing  1413  article----------------
# ---- processing  1414  article----------------
# ---- processing  1415  article----------------
# ---- processing  1416  article----------------
# ---- processing  1417  article----------------
# ---- processing  1418  article----------------
# ---- processing  1419  article----------------
# ---- processing  1420  article----------------
# ---- processing  1421  article----------------
# ---- processing  1422  article----------------
# ---- processing  1423  article----------------
# ---- processing  1424  article----------------
# ---- processing  1425  article----------------
# ---- processing  1426  article----------------
# ---- processing  1427  article----------------
# ---- processing  1428  article----------------
# ---- processing  1429  article----------------
# ---- processing  1430  article----------------
# ---- processing  1431  article----------------
# ---- processing  1432  article----------------
# ---- processing  1433  article----------------
# ---- processing  1434  article----------------
# ---- processing  1435  article----------------
# ---- processing  1436  article----------------
# ---- processing  1437  article----------------
# ---- processing  1438  article----------------
# ---- processing  1439  article----------------
# ---- processing  1440  article----------------
# ---- processing  1441  article----------------
# ---- processing  1442  article----------------
# ---- processing  1443  article----------------
# ---- processing  1444  article----------------
# ---- processing  1445  article----------------
# ---- processing  1446  article----------------
# ---- processing  1447  article----------------
# ---- processing  1448  article----------------
# ---- processing  1449  article----------------
# ---- processing  1450  article----------------
# ---- processing  1451  article----------------
# ---- processing  1452  article----------------
# ---- processing  1453  article----------------
# ---- processing  1454  article----------------
# ---- processing  1455  article----------------
# ---- processing  1456  article----------------
# ---- processing  1457  article----------------
# ---- processing  1458  article----------------
# ---- processing  1459  article----------------
