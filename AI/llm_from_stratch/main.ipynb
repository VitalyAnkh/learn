# %%
# !ls
# Out:
# ch2_working_with_text_data  main.py    pyproject.toml  uv.lock
# main.ipynb		    nohup.out  README.md

# %%
# retrieve the-verdict.txt from github
import urllib.request
url = url = ("https://raw.githubusercontent.com/rasbt/" "LLMs-from-scratch/main/ch02/01_main-chapter-code/" "the-verdict.txt")
file_path = "
