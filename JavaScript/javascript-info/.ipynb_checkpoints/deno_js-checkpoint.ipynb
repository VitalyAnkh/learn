// %%
alert("hello");

// %%
1 + 2
// Out:
// 3

// %%
let name = prompt("What's the official name of JavaScript?", "");
if (name == "ECMAScript") {
  alert("Right");
  console.log("hi!");
} else {
  alert("Wrong!");
}
// Out:
// What's the official name of JavaScript? ECMAScript
// hi!
